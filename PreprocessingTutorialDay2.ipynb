# %% [markdown]
# <a href="https://colab.research.google.com/github/subishinu/Brid_Subi/blob/main/PreprocessingTutorialDay2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as mtp
import pandas as pd

# %%
# Importing dataset
data = pd.read_csv('dataset.csv')
data.shape
# Out:
# (10, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Index      10 non-null     int64
#  1   Country    10 non-null     object
#  2   Age        9 non-null      float64
#  3   Salary     9 non-null      float64
#  4   Purchased  10 non-null     object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 528.0+ bytes

# %%
data.head()
# Out:
#    Index  Country   Age   Salary Purchased
# 0      0    India  38.0  68000.0        No
# 1      1   France  43.0  45000.0       Yes
# 2      2  Germany  30.0  54000.0        No
# 3      3   France  48.0  65000.0        No
# 4      4  Germany  40.0      NaN       Yes

# %%
data.describe()
# Out:
#           Index        Age        Salary
# count  10.00000   9.000000      9.000000
# mean    4.50000  41.111111  65222.222222
# std     3.02765   6.900081  14104.766728
# min     0.00000  30.000000  45000.000000
# 25%     2.25000  37.000000  54000.000000
# 50%     4.50000  40.000000  65000.000000
# 75%     6.75000  48.000000  77000.000000
# max     9.00000  50.000000  88000.000000

# %% [markdown]
# ## **Extracting independent variable:**

# %%
x=data.iloc[:,:-1].values

# %%
x
# Out:
# array([[0, 'India', 38.0, 68000.0],
#        [1, 'France', 43.0, 45000.0],
#        [2, 'Germany', 30.0, 54000.0],
#        [3, 'France', 48.0, 65000.0],
#        [4, 'Germany', 40.0, nan],
#        [5, 'India', 35.0, 58000.0],
#        [6, 'Germany', nan, 53000.0],
#        [7, 'France', 49.0, 79000.0],
#        [8, 'India', 50.0, 88000.0],
#        [9, 'France', 37.0, 77000.0]], dtype=object)
